# %%
exec(open('bc.py').read())
# Out:
# Maximum accuracy using Logistic Regression = 97.3684 with C = 3906.250000
# Time taken for LogReg = 0.04 seconds
# Neural Network with one hidden layer :
#
#
# Number of Hidden Units =  2
# Training Accuracy: 89.6703296703
# Test Accuracy: 88.5964912281
#
# Time taken for = 28.5913
#
# Number of Hidden Units =  4
# Training Accuracy: 90.5494505495
# Test Accuracy: 92.9824561404
#
# Time taken for = 30.9065
#
# Number of Hidden Units =  6
# Training Accuracy: 92.0879120879
# Test Accuracy: 87.7192982456
#
# Time taken for = 36.8828
#
# Number of Hidden Units =  8
# Training Accuracy: 95.3846153846
# Test Accuracy: 92.9824561404
#
# Time taken for = 40.5179
#
# Number of Hidden Units =  10
# Training Accuracy: 92.5274725275
# Test Accuracy: 92.1052631579
#
# Time taken for = 44.0609
#
# Number of Hidden Units =  12
# Training Accuracy: 93.1868131868
# Test Accuracy: 93.8596491228
#
# Time taken for = 43.7361
#
# Number of Hidden Units =  14
# Training Accuracy: 92.3076923077
# ...
