# %%
exec(open('bc.py').read())
# Out:
# Maximum accuracy using Logistic Regression = 96.4912 with C = 156.250000
# Time taken for LogReg = 0.03 seconds
# Neural Network with one hidden layer :
#
#
# Number of Hidden Units =  2
# Training Accuracy: 92.0879120879
# Test Accuracy: 89.4736842105
#
# Time taken for = 13.2508
# Training Accuracy: 92.0879120879
# Test Accuracy: 93.8596491228
# Time taken for  rbf  = 160.9119 seconds
#
# Accuracy using SVM with  rbf : 93.8596491228
# Time taken for  linear  = 165.7860 seconds
#
# Accuracy using SVM with  linear : 97.3684210526
# Time taken for  poly  = 471.1552 seconds
#
# Accuracy using SVM with  poly : 97.3684210526
# Time taken for  sigmoid  = 271.5509 seconds
#
# Accuracy using SVM with  sigmoid : 54.3859649123
#
# Time taken for Random Forest Classifier = 4.4342 seconds
#
# Accuracy with Random Forest Classifier =  97.3684210526
# Time taken for RandomForestClassifier with GMM = 89.02 seconds
#
# Accuracy with Random Forest Classifier using GMM = 96.4912
# ...
